# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/tinystories-narrative-classification/validation.csv
# /kaggle/input/tinystories-narrative-classification/train.csv

# %%
import pandas as pd

# %%
df = pd.read_csv("/kaggle/input/tinystories-narrative-classification/train.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2119719 entries, 0 to 2119718
# Data columns (total 1 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   text    object
# dtypes: object(1)
# memory usage: 16.2+ MB

# %%
df.head()
# Out:
#                                                 text
# 0  One day, a little girl named Lily found a need...
# 1  Once upon a time, there was a little car named...
# 2  One day, a little fish named Fin was swimming ...
# 3  Once upon a time, in a land full of trees, the...
# 4  Once upon a time, there was a little girl name...

# %%
import pandas as pd

df = pd.read_csv("/kaggle/input/tinystories-narrative-classification/train.csv")
print(df.info())  # Veri türleri ve eksik veriler hakkında bilgi almak için
print(df.head())  # İlk birkaç satırı görüntülemek için
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2119719 entries, 0 to 2119718
# Data columns (total 1 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   text    object
# dtypes: object(1)
# memory usage: 16.2+ MB
# None
#                                                 text
# 0  One day, a little girl named Lily found a need...
# 1  Once upon a time, there was a little car named...
# 2  One day, a little fish named Fin was swimming ...
# 3  Once upon a time, in a land full of trees, the...
# 4  Once upon a time, there was a little girl name...

# %%
print(df.isnull().sum())  # Eksik veri sayısını kontrol et
# Out:
# text    230
# dtype: int64

# %%
df.dropna(subset=['text'], inplace=True)
print(df.isnull().sum())  # Tekrar eksik veri kontrolü yapın
# Out:
# text    0
# dtype: int64

# %%
import re

# %%
# Elle stopwords listesi oluşturalım (İngilizce için temel durak kelimeler)
stopwords = ['the', 'and', 'is', 'in', 'to', 'of', 'a', 'that', 'it', 'on', 'for', 'with', 'as', 'by', 'at', 'an', 'this', 'be', 'from', 'or']

# Temizlik fonksiyonunu güncelleyelim
def clean_text(text):
    if isinstance(text, str):  # Sadece string tipindeki değerlere işlem yap
        text = text.lower()  # Tüm metni küçük harfe çevirme
        text = re.sub(r'\d+', '', text)  # Sayıları kaldırma
        text = re.sub(r'[^\w\s]', '', text)  # Noktalama işaretlerini kaldırma
        text = ' '.join([word for word in text.split() if word not in stopwords])  # Durak kelimeleri çıkarma
        return text
    return text  # Eğer metin değilse (örneğin NaN veya sayı), olduğu gibi döndür

# Temizleme fonksiyonunu veri çerçevesine uygulama
df['cleaned_text'] = df['text'].apply(clean_text)

# %%
print(df[['text', 'cleaned_text']].head())
# Out:
#                                                 text  \
# 0  One day, a little girl named Lily found a need...
# 1  Once upon a time, there was a little car named...
# 2  One day, a little fish named Fin was swimming ...
# 3  Once upon a time, in a land full of trees, the...
# 4  Once upon a time, there was a little girl name...
#
#                                         cleaned_text
# 0  one day little girl named lily found needle he...
# 1  once upon time there was little car named beep...
# 2  one day little fish named fin was swimming nea...
# 3  once upon time land full trees there was littl...
# 4  once upon time there was little girl named lil...

# %%
# İlk 5 satırı temizlenmiş metin sütunu ile görüntüleyin
print(df[['text', 'cleaned_text']].head())
# Out:
#                                                 text  \
# 0  One day, a little girl named Lily found a need...
# 1  Once upon a time, there was a little car named...
# 2  One day, a little fish named Fin was swimming ...
# 3  Once upon a time, in a land full of trees, the...
# 4  Once upon a time, there was a little girl name...
#
#                                         cleaned_text
# 0  one day little girl named lily found needle he...
# 1  once upon time there was little car named beep...
# 2  one day little fish named fin was swimming nea...
# 3  once upon time land full trees there was littl...
# 4  once upon time there was little girl named lil...

# %%
import pandas as pd

# CSV dosyasını yükleme
df = pd.read_csv('/kaggle/input/tinystories-narrative-classification/train.csv')

# Veri çerçevesinin ilk birkaç satırını görüntüleme
print(df.head())
# Out:
#                                                 text
# 0  One day, a little girl named Lily found a need...
# 1  Once upon a time, there was a little car named...
# 2  One day, a little fish named Fin was swimming ...
# 3  Once upon a time, in a land full of trees, the...
# 4  Once upon a time, there was a little girl name...

# %%
# 'cleaned_story' sütununun olup olmadığını kontrol etme
if 'cleaned_story' in df.columns:
    # Tekrar eden satırları kaldırma
    df.drop_duplicates(subset='cleaned_story', inplace=True)
    
    # Sonuçları kontrol etme
    print(df.head())
else:
    print("Veri çerçevesinde 'cleaned_story' adlı bir sütun bulunamadı.")
# Out:
# Veri çerçevesinde 'cleaned_story' adlı bir sütun bulunamadı.

# %%
import pandas as pd

# CSV dosyasını yükleme
df = pd.read_csv('/kaggle/input/tinystories-narrative-classification/train.csv')

# Sütun isimlerini görüntüleme
print(df.columns)
# Out:
# Index(['text'], dtype='object')

# %%
import pandas as pd

# Veri setini yükle
data = pd.read_csv("/kaggle/input/tinystories-narrative-classification/train.csv")

# İlk birkaç satırı görüntüleyerek doğru yüklendiğinden emin ol
data.head()
# Out:
#                                                 text
# 0  One day, a little girl named Lily found a need...
# 1  Once upon a time, there was a little car named...
# 2  One day, a little fish named Fin was swimming ...
# 3  Once upon a time, in a land full of trees, the...
# 4  Once upon a time, there was a little girl name...

# %%
# Tekrar eden satırları bul ve kaldır
data_cleaned = data.drop_duplicates()

# Temizlenmiş veri setinin boyutlarını görüntüle
print(f"Orijinal veri seti boyutu: {data.shape}")
print(f"Temizlenmiş veri seti boyutu: {data_cleaned.shape}")
# Out:
# Orijinal veri seti boyutu: (2119719, 1)
# Temizlenmiş veri seti boyutu: (1799249, 1)

# %%
# Veri setindeki sütunları görüntüle
print(data.columns)
# Out:
# Index(['text'], dtype='object')

# %%
print(data_cleaned.isnull().sum())
# Out:
# text    1
# dtype: int64

# %%
# Eksik satırları kaldır
data_cleaned = data_cleaned.dropna()

# Eksik veri olup olmadığını tekrar kontrol et
print(data_cleaned.isnull().sum())
# Out:
# text    0
# dtype: int64

# %%
# Metinleri küçük harfe çevir
data_cleaned['text'] = data_cleaned['text'].str.lower()

# %%
import re

# Fazla boşlukları tek boşluğa indir
data_cleaned['text'] = data_cleaned['text'].apply(lambda x: re.sub(r'\s+', ' ', x).strip())

# %%
# Temizlenmiş verinin ilk birkaç satırını görüntüle
print(data_cleaned['text'].head())
# Out:
# 0    one day, a little girl named lily found a need...
# 1    once upon a time, there was a little car named...
# 2    one day, a little fish named fin was swimming ...
# 3    once upon a time, in a land full of trees, the...
# 4    once upon a time, there was a little girl name...
# Name: text, dtype: object

# %%
# Veri setindeki satır sayısını görmek
print(f"Veri setinde {data_cleaned.shape[0]} satır var.")
# Out:
# Veri setinde 1799248 satır var.

# %%
import tensorflow as tf
print(tf.__version__)  # TensorFlow'un yüklü olup olmadığını ve sürümünü kontrol edin
# Out:
# 2.16.1

# %%
# NaN (boş) değerleri kaldırma
data_cleaned = data_cleaned.dropna(subset=['text'])

# Tüm verileri string'e çevirme ve fazla boşlukları temizleme
data_cleaned['text'] = data_cleaned['text'].astype(str).apply(lambda x: re.sub(r'\s+', ' ', x).strip())

# Temizlenmiş veriyi kontrol et
print(data_cleaned.head())
# Out:
#                                                 text
# 0  one day, a little girl named lily found a need...
# 1  once upon a time, there was a little car named...
# 2  one day, a little fish named fin was swimming ...
# 3  once upon a time, in a land full of trees, the...
# 4  once upon a time, there was a little girl name...

# %%
import pandas as pd

# Veri setinizi yükleyin
df = pd.read_csv('/kaggle/input/tinystories-narrative-classification/train.csv')

# İlk birkaç satırı görüntüleyin
print(df.head())

# Sütun isimlerini görüntüleyin
print(df.columns)
# Out:
#                                                 text
# 0  One day, a little girl named Lily found a need...
# 1  Once upon a time, there was a little car named...
# 2  One day, a little fish named Fin was swimming ...
# 3  Once upon a time, in a land full of trees, the...
# 4  Once upon a time, there was a little girl name...
# Index(['text'], dtype='object')

# %%
import pandas as pd

# Veri setini yükleyin
df = pd.read_csv('/kaggle/input/tinystories-narrative-classification/train.csv')

# Eksik verileri kontrol edin
print(df.isnull().sum())

# Eksik verileri içeren satırları kaldırın
df = df.dropna(subset=['text'])

# Temizlenmiş veri setini kontrol edin
print(df.isnull().sum())
# Out:
# text    230
# dtype: int64
# text    0
# dtype: int64

# %%
print(data_cleaned.head())
# Out:
#                                                 text
# 0  one day, a little girl named lily found a need...
# 1  once upon a time, there was a little car named...
# 2  one day, a little fish named fin was swimming ...
# 3  once upon a time, in a land full of trees, the...
# 4  once upon a time, there was a little girl name...

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF

# Veri setini yükleyin
df = pd.read_csv('/kaggle/input/tinystories-narrative-classification/train.csv')

# Eksik verileri temizleyin
df = df.dropna(subset=['text'])

# Veri setinin küçük bir örneğiyle çalışın (örneğin, ilk 1000 satır)
df_sample = df.sample(1000)

# Metin verisini içeren sütunu alın
texts = df_sample['text'].values

# Metin verisini sayısal verilere dönüştürün
vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(texts)

# NMF modelini oluşturun
nmf_model = NMF(n_components=5, random_state=0)
nmf_model.fit(X)

# Konu terimlerini inceleyin
for index, topic in enumerate(nmf_model.components_):
    print(f"Topic #{index}:")
    print([vectorizer.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
# Out:
# Topic #0:
# ['loved', 'day', 'girl', 'named', 'play', 'said', 'max', 'mommy', 'mom', 'lily']
# Topic #1:
# ['lion', 'car', 'loved', 'toy', 'day', 'named', 'play', 'mommy', 'boy', 'timmy']
# Topic #2:
# ['time', 'man', 'day', 'boy', 'jack', 'mom', 'girl', 'little', 'said', 'tim']
# Topic #3:
# ['sara', 'sam', 'car', 'mom', 'dog', 'mia', 'anna', 'says', 'ben', 'tom']
# Topic #4:
# ['friends', 'sky', 'bunny', 'help', 'little', 'tree', 'flew', 'nest', 'fly', 'bird']

# %%
import numpy as np

# Her bir hikaye için NMF modelinin konu dağılımlarını al
topic_distributions = nmf_model.transform(X)

# En yüksek olasılığa sahip olan konuyu her hikaye için etiket olarak ata
df_sample['topic_label'] = np.argmax(topic_distributions, axis=1)

# Etiketlenmiş veriyi kontrol edelim
print(df_sample[['text', 'topic_label']].head())
# Out:
#                                                       text  topic_label
# 1243131  Once upon a time, there was a little boy named...            1
# 14660    Once upon a time, there was a big castle. The ...            2
# 1934598  Once upon a time there was a girl called Zoe. ...            2
# 1378612  Once upon a time, there was a boy named Timmy....            1
# 1083476  Once upon a time, there was a little girl name...            2

# %%
# İlk 10 satırı görmek için
print(df_sample[['text', 'topic_label']].head(10))

# Belirli bir konuya ait hikayeleri görmek için (örneğin, 'topic_label' 2 olanlar)
print(df_sample[df_sample['topic_label'] == 2][['text', 'topic_label']])

# Tüm etiketi olan veriyi CSV dosyasına kaydetmek istersen:
df_sample.to_csv('etiketli_veri.csv', index=False)
# Out:
#                                                       text  topic_label
# 1243131  Once upon a time, there was a little boy named...            1
# 14660    Once upon a time, there was a big castle. The ...            2
# 1934598  Once upon a time there was a girl called Zoe. ...            2
# 1378612  Once upon a time, there was a boy named Timmy....            1
# 1083476  Once upon a time, there was a little girl name...            2
# 882676   Anna and Ben are twins. They like to play with...            3
# 388618   Once upon a time, there was a boy named Timmy....            1
# 515266   Once upon a time, there was a bear named Bob w...            2
# 1783954  Once upon a time, there was a black bear. He l...            2
# 883087   Once there was a bunny named Tom. Tom was alwa...            3
#                                                       text  topic_label
# 14660    Once upon a time, there was a big castle. The ...            2
# 1934598  Once upon a time there was a girl called Zoe. ...            2
# 1083476  Once upon a time, there was a little girl name...            2
# 515266   Once upon a time, there was a bear named Bob w...            2
# 1783954  Once upon a time, there was a black bear. He l...            2
# ...                                                    ...          ...
# 1332509  One day, there was a girl who was very foolish...            2
# 1173444  John was a 3 year old boy who loved to explore...            2
# 1433982  Once upon a time there was a little boy. His n...            2
# 762927   Once upon a time, there was a little girl who ...            2
# 732149   John had a hammer. He was only 3 years old and...            2
#
# [588 rows x 2 columns]

# %%
# Topic Label 0 olan hikayeleri gör
topic_0_stories = df_sample[df_sample['topic_label'] == 0]
print(topic_0_stories[['text', 'topic_label']])

# Topic Label 1 olan hikayeleri gör
topic_1_stories = df_sample[df_sample['topic_label'] == 1]
print(topic_1_stories[['text', 'topic_label']])
# Out:
#                                                       text  topic_label
# 1078897  Once upon a time, there was a little girl name...            0
# 514863   Lily and Lila were twins who liked to play out...            0
# 2031312  Once upon a time, there was a little girl name...            0
# 855920   Once upon a time, there was a little girl name...            0
# 190247   Once upon a time, there was a little girl name...            0
# ...                                                    ...          ...
# 1054079  Once upon a time, there was a beautiful girl n...            0
# 754347   Lily wanted to ride her bicycle with her big s...            0
# 738215   One day, a little girl named Lily started to f...            0
# 1460071  Once upon a time, there was a little girl name...            0
# 698367   Ben and Lily were playing with their snowman i...            0
#
# [153 rows x 2 columns]
#                                                       text  topic_label
# 1243131  Once upon a time, there was a little boy named...            1
# 1378612  Once upon a time, there was a boy named Timmy....            1
# 388618   Once upon a time, there was a boy named Timmy....            1
# 1331075  Once upon a time, there was a little boy named...            1
# 1488108  Once upon a time, there was a little boy named...            1
# 133708   Once upon a time, there was a boy named Timmy....            1
# 1900064  Timmy wanted to play basketball with his dad. ...            1
# 1021170  Once upon a time, there was a little boy named...            1
# 928908   Once upon a time, there was a boy named Timmy....            1
# 1077157  Once upon a time, there was a little mouse nam...            1
# 112770   Once upon a time, there was a little girl name...            1
# 734696   Once upon a time, there was a little boy named...            1
# 511459   Once upon a time, there was a boy named Timmy....            1
# 647642   Once upon a time, there was a boy named Timmy ...            1
# 1967121  Once upon a time, there was a little mouse nam...            1
# 1601532  Once upon a time, there was a little boy named...            1
# 1307984  Once upon a time, there was a little boy named...            1
# 316780   Once upon a time, there was a little boy named...            1
# 1835477  Once upon a time, there was a boy named Timmy....            1
# 260705   Once upon a time, there was a little boy named...            1
# 406909   Once upon a time there was a little boy called...            1
# 1184842  One day, Little Timmy was feeling very sad. He...            1
# 486969   Once upon a time, there was a little boy named...            1
# 217353   Once upon a time, there was a little boy named...            1
# 1785976  Once upon a time, there was a little girl name...            1
# 61157    Once upon a time, there was a little boy named...            1
# 1128369  Once upon a time, there was a little boy named...            1
# 1162179  Once upon a time, there was a little boy named...            1
# 1129998  Once upon a time, there was a little boy named...            1
# 994981   Once upon a time, there was a little boy named...            1
# 1109004  Once upon a time, there was a boy named Timmy....            1
# 1783490  One sunny day, a boy named Timmy and his dad w...            1
# 1668647  Once upon a time, there was a boy named Timmy....            1
# 541310   Once upon a time, there was a little boy named...            1
# 17370    Once upon a time, there was a boy named Timmy....            1
# 564181   Once upon a time, there was a little boy named...            1
# 1954511  Once upon a time, there was a little boy named...            1
# 954029   Once upon a time, there was a little boy named...            1
# 39770    Once upon a time, there was a big dog named Ma...            1
# 1985578  Timmy was feeling fancy. He put his nicest clo...            1
# 1448539  Once upon a time, there was a little girl name...            1
# 1739846  Once upon a time, there was a boy named Timmy....            1
# 835761   Once upon a time, there was a little boy named...            1
# 1654620  Once upon a time, there was a boy named Timmy....            1
# 1624827  Once upon a time, there were two best friends,...            1
# 1577205  Once upon a time, there was a little boy named...            1
# 1570066  Once upon a time, there was a happy boy named ...            1
# 1936901  Once upon a time, there was a little boy named...            1
# 1554130  Once upon a time, there was a little boy named...            1
# 594683   Once upon a time, there was a little girl name...            1
# 1690741  Once upon a time, there was a little boy named...            1
# 1483     Once upon a time, there was a unique little bi...            1
# 881907   It was a sunny morning and Timmy was feeling e...            1
# 1104742  Once upon a time, there was a little boy named...            1
# 1100435  Timmy had been feeling unwell for a few days. ...            1
# 1678171  Once upon a time, there was a little boy named...            1
# 1414798  Once upon a time, there was a little boy named...            1
# 422704   Once upon a time, there was a little boy named...            1

# %%
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Text verisini hazırlayın (girdi verisi olarak kullanacağız)
texts = df_sample['text'].values

# Tokenizer oluşturun
tokenizer = Tokenizer()
tokenizer.fit_on_texts(texts)

# Metinleri sayısal verilere dönüştürün (tokenizasyon)
sequences = tokenizer.texts_to_sequences(texts)

# Verileri aynı uzunluğa getirin (padding işlemi)
maxlen = 100  # Giriş uzunluğu olarak 100 seçtim, bunu ihtiyaca göre artırabilirsiniz
X = pad_sequences(sequences, maxlen=maxlen)

# Konu etiketlerini hedef değerler (output) olarak kullanacağız
y = df_sample['topic_label'].values

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense

# Modeli oluşturun
model = Sequential()

# Embedding katmanı (her kelimeyi bir vektör temsil edecek)
model.add(Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=50))

# RNN katmanı
model.add(SimpleRNN(128, return_sequences=False))

# Çıkış katmanı (5 farklı konu olduğu için)
model.add(Dense(5, activation='softmax'))

# Modeli derleyin
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Modeli eğitin
model.fit(X, y, epochs=10, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.5010 - loss: 1.3549 - val_accuracy: 0.5350 - val_loss: 1.4276
# Epoch 2/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.5718 - loss: 1.2505 - val_accuracy: 0.5350 - val_loss: 1.3736
# Epoch 3/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.6317 - loss: 1.0138 - val_accuracy: 0.5350 - val_loss: 1.3416
# Epoch 4/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.7002 - loss: 0.7996 - val_accuracy: 0.5350 - val_loss: 1.4068
# Epoch 5/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.7544 - loss: 0.7112 - val_accuracy: 0.5200 - val_loss: 1.4203
# Epoch 6/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.8650 - loss: 0.4689 - val_accuracy: 0.5050 - val_loss: 1.4730
# Epoch 7/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9801 - loss: 0.2254 - val_accuracy: 0.4650 - val_loss: 1.5918
# Epoch 8/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9892 - loss: 0.1288 - val_accuracy: 0.4800 - val_loss: 1.6987
# Epoch 9/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 1.0000 - loss: 0.0548 - val_accuracy: 0.4450 - val_loss: 1.7857
# Epoch 10/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 1.0000 - loss: 0.0268 - val_accuracy: 0.4150 - val_loss: 1.8705

# %%
# Yeni bir kelime girdisi verelim
new_input = ['dog']

# Tokenizer kullanarak yeni girdiyi sayısal forma dönüştürelim
new_sequence = tokenizer.texts_to_sequences(new_input)
new_sequence = pad_sequences(new_sequence, maxlen=maxlen)

# Modelin tahminini alalım
predicted_topic = model.predict(new_sequence)

# En yüksek olasılıkla tahmin edilen konuyu belirleyelim
predicted_label = np.argmax(predicted_topic)

# O konuya ait bir hikaye seçip yazdıralım
predicted_story = df_sample[df_sample['topic_label'] == predicted_label].sample(1)['text'].values[0]
print(f"Tahmin edilen konu: {predicted_label}, Hikaye: {predicted_story}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# Tahmin edilen konu: 2, Hikaye: Once upon a time, there lived two friends: a rabbit and a frog. Both were always very happy and loved to play together.
# One day, they decided to go on an adventure and they decided to jump around in a field of daisies.
# The rabbit jumped high and far and could not stop jumping. It was having so much fun!
# But the frog was not so brave. Instead, it jumped low and slow.
# The rabbit thought that was foolish and laughed at the frog.
# The frog was sad and decided to stay still for a while.
# Suddenly, the rabbit felt sorry for being so mean. It turned to the frog and said: "Life is too short to be careful all the time - jump higher and enjoy it!"
# The frog was so happy and started jumping around with the rabbit.
# They both switched off the foolish thoughts and jumped together in the daisies.
# They both learned that it is important to be brave and to enjoy life.

# %%
# Üç kelimelik yeni bir girdi verelim
new_input = ['dog', 'play', 'park']

# Tokenizer kullanarak yeni girdiyi sayısal forma dönüştürelim
new_sequence = tokenizer.texts_to_sequences([' '.join(new_input)])
new_sequence = pad_sequences(new_sequence, maxlen=maxlen)

# Modelin tahminini alalım
predicted_topic = model.predict(new_sequence)

# En yüksek olasılıkla tahmin edilen konuyu belirleyelim
predicted_label = np.argmax(predicted_topic)

# O konuya ait bir hikaye seçip yazdıralım
predicted_story = df_sample[df_sample['topic_label'] == predicted_label].sample(1)['text'].values[0]
print(f"Tahmin edilen konu: {predicted_label}, Hikaye: {predicted_story}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Tahmin edilen konu: 2, Hikaye: Once there was a kind little girl. She loved to go to the zoo and see all of the animals.
#
# One day when she was at the zoo, she saw a very big animal. She was scared at first but then saw that it was very kind and just wanted to be her friend.
#
# The little girl and the animal became very good friends. They talked and laughed and had lots of fun.
#
# Whenever the girl was scared of something, the animal would give her a gentle smile and tell her not to worry.
#
# The little girl was never scared to go to the zoo again, because she knew her animal friend was always there waiting for her.

# %%
# 'dog' kelimesini içeren hikayeleri filtrele
filtered_stories = df_sample[df_sample['text'].str.contains('dog', case=False)]

# Eğer bu kelimeyi içeren bir hikaye varsa, rastgele bir tanesini seç
if not filtered_stories.empty:
    predicted_story = filtered_stories.sample(1)['text'].values[0]
    print(f"'dog' kelimesini içeren hikaye: {predicted_story}")
else:
    print("'dog' kelimesini içeren bir hikaye bulunamadı.")
# Out:
# 'dog' kelimesini içeren hikaye: Lily was a large dog who liked to play with her toys. She had a ball, a bone, a rope and a teddy bear. She always kept them in her basket, where they belonged. She did not like to share them with anyone.
#
# One day, a new dog came to live in the house next door. His name was Max, and he was very curious. He saw Lily playing with her toys in the garden, and he wanted to join her. He jumped over the fence and ran towards her.
#
# "Hi, I'm Max. Can I play with you?" he asked.
#
# Lily growled and barked. "No, you can't. These are my toys. They belong to me. Go away!"
#
# Max was sad and confused. He did not understand why Lily was so mean. He just wanted to make a friend. He decided to be patient and try again later.
#
# The next day, he saw Lily sleeping in her basket. He thought it was a good chance to borrow one of her toys. He sneaked over the fence and picked up the teddy bear. He thought it was very soft and cuddly.
#
# But Lily woke up and saw him. She was very angry. She jumped out of her basket and chased him. "Give me back my teddy bear! It belongs to me!" she shouted.
#
# Max was scared and ran away. He dropped the teddy bear and ran back to his house. He felt sorry and ashamed. He did not mean to upset Lily. He just wanted to play with her.
#
# The next day, he saw Lily sitting in the garden. She looked bored and lonely. He felt sorry for her. He decided to try one more time. He brought his own toy, a squeaky duck, and threw it over the fence. He hoped Lily would like it.
#
# Lily heard the squeak and saw the duck. She was curious and picked it up. She liked the sound and the feel of it. She looked over the fence and saw Max. He smiled and wagged his tail.
#
# "Hi, I'm Max. Can I play with you?" he asked again.
#
# Lily thought for a moment. She realized that Max was not a bad dog. He was just a friendly dog. She decided to give him a chance. She smiled and wagged her tail too.
#
# "Hi, I'm Lily. Yes, you can play with me. This is a nice toy. Thank you for sharing it with me." she said.
#
# Max was happy and jumped over the fence. He and Lily played with the duck and the teddy bear. They had a lot of fun. They became friends.
#
# Lily learned that sharing was good. She did not need to keep all her toys to herself. She could let Max play with them too. They belonged to both of them. She was glad that Max was patient and kind. He was a good friend.

# %%
# 'dog' kelimesini içeren hikayeleri filtrele
filtered_stories = df_sample[df_sample['text'].str.contains('dog', case=False)]

# Eğer bu kelimeyi içeren bir hikaye varsa, rastgele bir tanesini seç
if not filtered_stories.empty:
    predicted_story = filtered_stories.sample(1)['text'].values[0]
    print(f"'dog' kelimesini içeren hikaye: {predicted_story}")
else:
    print("'dog' kelimesini içeren bir hikaye bulunamadı.")
# Out:
# 'dog' kelimesini içeren hikaye: Once upon a time there was a brave doggy. He wanted to explore the world, so one day he put on his leash and began to crawl. He crawled around the house, around the garden and then in to the woods.
#
# In the woods there was an old, tall tree. He crawled slowly around it and saw lots of interesting things like bugs, flowers and birds. Suddenly, he came across a big scary snake. Oh no!
#
# The brave doggy didn't panic. He didn't bark or run away, he just stared at the snake. Then he slowly crawled backwards, away from the snake and back home.
#
# The brave doggy was so happy that he made it back home safely. He knew that if he was brave and careful, he could explore the world and have fun!

# %%
model.save('model.h5')

# %%
import pickle
with open('tokenizer.pkl', 'wb') as f:
    pickle.dump(tokenizer, f)

# %%
import os

# Mevcut çalışma dizinindeki dosyaları listele
for file in os.listdir():
    print(file)
# Out:
# model.h5
# tokenizer.pkl
# etiketli_veri.csv
# .virtual_documents
